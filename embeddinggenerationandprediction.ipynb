# %% [markdown]
# # Embedding Generation and Prediction

# %% [markdown]
# ## Generate Embeddings for All Possible Combinations

# %%
import pandas as pd
import numpy as np

# %%
#set variables according to docker instance
uri = "bolt://localhost:7687"
username = "neo4j"
password = "password"

# %%
#connect with driver
from neo4j import GraphDatabase
with GraphDatabase.driver(uri,auth=(username,password)) as driver:
  driver.verify_connectivity()

# %%
#setup GDS
from re import U
from graphdatascience import GraphDataScience

gds = GraphDataScience(uri, auth=(username,password))

# %%
#method that clears all graphs in memory - can only have a specific amount according to memory
def clearGraphs():
    driver.execute_query(
        """
        CALL gds.graph.list()
        YIELD graphName
        WITH collect(graphName) AS graphs
        UNWIND graphs AS graph
        CALL gds.graph.drop(graph) YIELD graphName
        RETURN graphName
        """
    )

# %%
import itertools

# Define the variations for each field
fields_variations = {
    "pregnancies" : ["low pregnancies", "normal pregnancies", "high pregnancies"],
    "glucose" : ["low glucose", "normal glucose", "high glucose"],
    "blood_pressure" : ["low blood pressure", "normal blood pressure", "high blood pressure"],
    "skin_thickness" : ["low skin thickness", "normal skin thickness", "high skin thickness"],
    "insulin" : ["low insulin", "normal insulin", "high insulin"],
    "bmi" : ["low bmi", "normal bmi", "high bmi"],
    "diabetes_pedigree_function" : ["low diabetes pedigree function", "normal diabetes pedigree function", "high diabetes pedigree function"],
    "age" : ["low age", "normal age", "high age"]
}

relationships = {
    "low pregnancies": "HAS_PREGNANCIES",
    "normal pregnancies": "HAS_PREGNANCIES",
    "high pregnancies": "HAS_PREGNANCIES",
    "low glucose": "HAS_GLUCOSE",
    "normal glucose": "HAS_GLUCOSE",
    "high glucose": "HAS_GLUCOSE",
    "low blood pressure": "HAS_BLOOD_PRESSURE",
    "normal blood pressure": "HAS_BLOOD_PRESSURE",
    "high blood pressure": "HAS_BLOOD_PRESSURE",
    "low skin thickness": "HAS_SKIN_THICKNESS",
    "normal skin thickness": "HAS_SKIN_THICKNESS",
    "high skin thickness": "HAS_SKIN_THICKNESS",
    "low insulin": "HAS_INSULIN",
    "normal insulin": "HAS_INSULIN",
    "high insulin": "HAS_INSULIN",
    "low bmi": "HAS_BMI",
    "normal bmi": "HAS_BMI",
    "high bmi": "HAS_BMI",
    "low diabetes pedigree function": "HAS_DIABETES_PEDIGREE_FUNCTION",
    "normal diabetes pedigree function": "HAS_DIABETES_PEDIGREE_FUNCTION",
    "high diabetes pedigree function": "HAS_DIABETES_PEDIGREE_FUNCTION",
    "low age": "HAS_AGE",
    "normal age": "HAS_AGE",
    "high age": "HAS_AGE"
}

# %%
def generate_combinations(fields_variations, combination_size):
    # Get all field names
    field_names = list(fields_variations.keys())

    # Get all possible combinations of the specified size
    field_combinations = list(itertools.combinations(field_names, combination_size))

    # Function to generate all combinations of variations for a given set of fields
    def get_variations(fields):
        variations = [fields_variations[field] for field in fields]
        return list(itertools.product(*variations))

    # Generate all combinations for each set of fields
    all_combinations = []
    for fields in field_combinations:
        combinations = get_variations(fields)
        all_combinations.extend(combinations)

    # Convert to list of lists
    combinations_list = [list(combination) for combination in all_combinations]

    return combinations_list

# %%
generate_combinations(fields_variations, 3) #example usage
# Out:
# [['low pregnancies', 'low glucose', 'low blood pressure'],
#  ['low pregnancies', 'low glucose', 'normal blood pressure'],
#  ['low pregnancies', 'low glucose', 'high blood pressure'],
#  ['low pregnancies', 'normal glucose', 'low blood pressure'],
#  ['low pregnancies', 'normal glucose', 'normal blood pressure'],
#  ['low pregnancies', 'normal glucose', 'high blood pressure'],
#  ['low pregnancies', 'high glucose', 'low blood pressure'],
#  ['low pregnancies', 'high glucose', 'normal blood pressure'],
#  ['low pregnancies', 'high glucose', 'high blood pressure'],
#  ['normal pregnancies', 'low glucose', 'low blood pressure'],
#  ['normal pregnancies', 'low glucose', 'normal blood pressure'],
#  ['normal pregnancies', 'low glucose', 'high blood pressure'],
#  ['normal pregnancies', 'normal glucose', 'low blood pressure'],
#  ['normal pregnancies', 'normal glucose', 'normal blood pressure'],
#  ['normal pregnancies', 'normal glucose', 'high blood pressure'],
#  ['normal pregnancies', 'high glucose', 'low blood pressure'],
#  ['normal pregnancies', 'high glucose', 'normal blood pressure'],
#  ['normal pregnancies', 'high glucose', 'high blood pressure'],
#  ['high pregnancies', 'low glucose', 'low blood pressure'],
#  ['high pregnancies', 'low glucose', 'normal blood pressure'],
#  ['high pregnancies', 'low glucose', 'high blood pressure'],
#  ['high pregnancies', 'normal glucose', 'low blood pressure'],
#  ['high pregnancies', 'normal glucose', 'normal blood pressure'],
#  ['high pregnancies', 'normal glucose', 'high blood pressure'],
#  ['high pregnancies', 'high glucose', 'low blood pressure'],
#  ['high pregnancies', 'high glucose', 'normal blood pressure'],
#  ['high pregnancies', 'high glucose', 'high blood pressure'],
#  ['low pregnancies', 'low glucose', 'low skin thickness'],
#  ['low pregnancies', 'low glucose', 'normal skin thickness'],
#  ['low pregnancies', 'low glucose', 'high skin thickness'],
#  ['low pregnancies', 'normal glucose', 'low skin thickness'],
#  ['low pregnancies', 'normal glucose', 'normal skin thickness'],
#  ['low pregnancies', 'normal glucose', 'high skin thickness'],
#  ['low pregnancies', 'high glucose', 'low skin thickness'],
#  ['low pregnancies', 'high glucose', 'normal skin thickness'],
#  ['low pregnancies', 'high glucose', 'high skin thickness'],
#  ['normal pregnancies', 'low glucose', 'low skin thickness'],
#  ['normal pregnancies', 'low glucose', 'normal skin thickness'],
#  ['normal pregnancies', 'low glucose', 'high skin thickness'],
#  ['normal pregnancies', 'normal glucose', 'low skin thickness'],
#  ['normal pregnancies', 'normal glucose', 'normal skin thickness'],
#  ['normal pregnancies', 'normal glucose', 'high skin thickness'],
#  ['normal pregnancies', 'high glucose', 'low skin thickness'],
#  ['normal pregnancies', 'high glucose', 'normal skin thickness'],
#  ['normal pregnancies', 'high glucose', 'high skin thickness'],
#  ['high pregnancies', 'low glucose', 'low skin thickness'],
#  ['high pregnancies', 'low glucose', 'normal skin thickness'],
#  ['high pregnancies', 'low glucose', 'high skin thickness'],
#  ['high pregnancies', 'normal glucose', 'low skin thickness'],
#  ['high pregnancies', 'normal glucose', 'normal skin thickness'],
#  ['high pregnancies', 'normal glucose', 'high skin thickness'],
#  ['high pregnancies', 'high glucose', 'low skin thickness'],
#  ['high pregnancies', 'high glucose', 'normal skin thickness'],
#  ['high pregnancies', 'high glucose', 'high skin thickness'],
#  ['low pregnancies', 'low glucose', 'low insulin'],
#  ['low pregnancies', 'low glucose', 'normal insulin'],
#  ['low pregnancies', 'low glucose', 'high insulin'],
#  ['low pregnancies', 'normal glucose', 'low insulin'],
#  ['low pregnancies', 'normal glucose', 'normal insulin'],
#  ['low pregnancies', 'normal glucose', 'high insulin'],
#  ['low pregnancies', 'high glucose', 'low insulin'],
#  ['low pregnancies', 'high glucose', 'normal insulin'],
#  ['low pregnancies', 'high glucose', 'high insulin'],
#  ['normal pregnancies', 'low glucose', 'low insulin'],
#  ['normal pregnancies', 'low glucose', 'normal insulin'],
#  ['normal pregnancies', 'low glucose', 'high insulin'],
#  ['normal pregnancies', 'normal glucose', 'low insulin'],
#  ['normal pregnancies', 'normal glucose', 'normal insulin'],
#  ['normal pregnancies', 'normal glucose', 'high insulin'],
#  ['normal pregnancies', 'high glucose', 'low insulin'],
#  ['normal pregnancies', 'high glucose', 'normal insulin'],
#  ['normal pregnancies', 'high glucose', 'high insulin'],
#  ['high pregnancies', 'low glucose', 'low insulin'],
#  ['high pregnancies', 'low glucose', 'normal insulin'],
#  ['high pregnancies', 'low glucose', 'high insulin'],
#  ['high pregnancies', 'normal glucose', 'low insulin'],
#  ['high pregnancies', 'normal glucose', 'normal insulin'],
#  ['high pregnancies', 'normal glucose', 'high insulin'],
#  ['high pregnancies', 'high glucose', 'low insulin'],
#  ['high pregnancies', 'high glucose', 'normal insulin'],
#  ['high pregnancies', 'high glucose', 'high insulin'],
#  ['low pregnancies', 'low glucose', 'low bmi'],
#  ['low pregnancies', 'low glucose', 'normal bmi'],
#  ['low pregnancies', 'low glucose', 'high bmi'],
#  ['low pregnancies', 'normal glucose', 'low bmi'],
#  ['low pregnancies', 'normal glucose', 'normal bmi'],
#  ['low pregnancies', 'normal glucose', 'high bmi'],
#  ['low pregnancies', 'high glucose', 'low bmi'],
#  ['low pregnancies', 'high glucose', 'normal bmi'],
#  ['low pregnancies', 'high glucose', 'high bmi'],
#  ['normal pregnancies', 'low glucose', 'low bmi'],
#  ['normal pregnancies', 'low glucose', 'normal bmi'],
#  ['normal pregnancies', 'low glucose', 'high bmi'],
#  ['normal pregnancies', 'normal glucose', 'low bmi'],
#  ['normal pregnancies', 'normal glucose', 'normal bmi'],
#  ['normal pregnancies', 'normal glucose', 'high bmi'],
#  ['normal pregnancies', 'high glucose', 'low bmi'],
#  ['normal pregnancies', 'high glucose', 'normal bmi'],
#  ['normal pregnancies', 'high glucose', 'high bmi'],
#  ['high pregnancies', 'low glucose', 'low bmi'],
#  ['high pregnancies', 'low glucose', 'normal bmi'],
#  ['high pregnancies', 'low glucose', 'high bmi'],
#  ['high pregnancies', 'normal glucose', 'low bmi'],
#  ['high pregnancies', 'normal glucose', 'normal bmi'],
#  ['high pregnancies', 'normal glucose', 'high bmi'],
#  ['high pregnancies', 'high glucose', 'low bmi'],
#  ['high pregnancies', 'high glucose', 'normal bmi'],
#  ['high pregnancies', 'high glucose', 'high bmi'],
#  ['low pregnancies', 'low glucose', 'low diabetes pedigree function'],
#  ['low pregnancies', 'low glucose', 'normal diabetes pedigree function'],
#  ['low pregnancies', 'low glucose', 'high diabetes pedigree function'],
#  ['low pregnancies', 'normal glucose', 'low diabetes pedigree function'],
#  ['low pregnancies', 'normal glucose', 'normal diabetes pedigree function'],
#  ['low pregnancies', 'normal glucose', 'high diabetes pedigree function'],
#  ['low pregnancies', 'high glucose', 'low diabetes pedigree function'],
#  ['low pregnancies', 'high glucose', 'normal diabetes pedigree function'],
#  ['low pregnancies', 'high glucose', 'high diabetes pedigree function'],
#  ['normal pregnancies', 'low glucose', 'low diabetes pedigree function'],
#  ['normal pregnancies', 'low glucose', 'normal diabetes pedigree function'],
#  ['normal pregnancies', 'low glucose', 'high diabetes pedigree function'],
#  ['normal pregnancies', 'normal glucose', 'low diabetes pedigree function'],
#  ['normal pregnancies', 'normal glucose', 'normal diabetes pedigree function'],
#  ['normal pregnancies', 'normal glucose', 'high diabetes pedigree function'],
#  ['normal pregnancies', 'high glucose', 'low diabetes pedigree function'],
#  ['normal pregnancies', 'high glucose', 'normal diabetes pedigree function'],
#  ['normal pregnancies', 'high glucose', 'high diabetes pedigree function'],
#  ['high pregnancies', 'low glucose', 'low diabetes pedigree function'],
#  ['high pregnancies', 'low glucose', 'normal diabetes pedigree function'],
#  ['high pregnancies', 'low glucose', 'high diabetes pedigree function'],
#  ['high pregnancies', 'normal glucose', 'low diabetes pedigree function'],
#  ['high pregnancies', 'normal glucose', 'normal diabetes pedigree function'],
#  ['high pregnancies', 'normal glucose', 'high diabetes pedigree function'],
#  ['high pregnancies', 'high glucose', 'low diabetes pedigree function'],
#  ['high pregnancies', 'high glucose', 'normal diabetes pedigree function'],
#  ['high pregnancies', 'high glucose', 'high diabetes pedigree function'],
#  ['low pregnancies', 'low glucose', 'low age'],
#  ['low pregnancies', 'low glucose', 'normal age'],
#  ['low pregnancies', 'low glucose', 'high age'],
#  ['low pregnancies', 'normal glucose', 'low age'],
#  ['low pregnancies', 'normal glucose', 'normal age'],
#  ['low pregnancies', 'normal glucose', 'high age'],
#  ['low pregnancies', 'high glucose', 'low age'],
#  ['low pregnancies', 'high glucose', 'normal age'],
#  ['low pregnancies', 'high glucose', 'high age'],
#  ['normal pregnancies', 'low glucose', 'low age'],
#  ['normal pregnancies', 'low glucose', 'normal age'],
#  ['normal pregnancies', 'low glucose', 'high age'],
#  ['normal pregnancies', 'normal glucose', 'low age'],
#  ['normal pregnancies', 'normal glucose', 'normal age'],
#  ['normal pregnancies', 'normal glucose', 'high age'],
#  ['normal pregnancies', 'high glucose', 'low age'],
#  ['normal pregnancies', 'high glucose', 'normal age'],
#  ['normal pregnancies', 'high glucose', 'high age'],
#  ['high pregnancies', 'low glucose', 'low age'],
#  ['high pregnancies', 'low glucose', 'normal age'],
#  ['high pregnancies', 'low glucose', 'high age'],
#  ['high pregnancies', 'normal glucose', 'low age'],
#  ['high pregnancies', 'normal glucose', 'normal age'],
#  ['high pregnancies', 'normal glucose', 'high age'],
#  ['high pregnancies', 'high glucose', 'low age'],
#  ['high pregnancies', 'high glucose', 'normal age'],
#  ['high pregnancies', 'high glucose', 'high age'],
#  ['low pregnancies', 'low blood pressure', 'low skin thickness'],
#  ['low pregnancies', 'low blood pressure', 'normal skin thickness'],
#  ['low pregnancies', 'low blood pressure', 'high skin thickness'],
#  ['low pregnancies', 'normal blood pressure', 'low skin thickness'],
#  ['low pregnancies', 'normal blood pressure', 'normal skin thickness'],
#  ['low pregnancies', 'normal blood pressure', 'high skin thickness'],
#  ['low pregnancies', 'high blood pressure', 'low skin thickness'],
#  ['low pregnancies', 'high blood pressure', 'normal skin thickness'],
#  ['low pregnancies', 'high blood pressure', 'high skin thickness'],
#  ['normal pregnancies', 'low blood pressure', 'low skin thickness'],
#  ['normal pregnancies', 'low blood pressure', 'normal skin thickness'],
#  ['normal pregnancies', 'low blood pressure', 'high skin thickness'],
#  ['normal pregnancies', 'normal blood pressure', 'low skin thickness'],
#  ['normal pregnancies', 'normal blood pressure', 'normal skin thickness'],
#  ['normal pregnancies', 'normal blood pressure', 'high skin thickness'],
#  ['normal pregnancies', 'high blood pressure', 'low skin thickness'],
#  ['normal pregnancies', 'high blood pressure', 'normal skin thickness'],
#  ['normal pregnancies', 'high blood pressure', 'high skin thickness'],
#  ['high pregnancies', 'low blood pressure', 'low skin thickness'],
#  ['high pregnancies', 'low blood pressure', 'normal skin thickness'],
#  ['high pregnancies', 'low blood pressure', 'high skin thickness'],
#  ['high pregnancies', 'normal blood pressure', 'low skin thickness'],
#  ['high pregnancies', 'normal blood pressure', 'normal skin thickness'],
#  ['high pregnancies', 'normal blood pressure', 'high skin thickness'],
#  ['high pregnancies', 'high blood pressure', 'low skin thickness'],
#  ['high pregnancies', 'high blood pressure', 'normal skin thickness'],
#  ['high pregnancies', 'high blood pressure', 'high skin thickness'],
#  ['low pregnancies', 'low blood pressure', 'low insulin'],
#  ['low pregnancies', 'low blood pressure', 'normal insulin'],
#  ['low pregnancies', 'low blood pressure', 'high insulin'],
#  ['low pregnancies', 'normal blood pressure', 'low insulin'],
#  ['low pregnancies', 'normal blood pressure', 'normal insulin'],
#  ['low pregnancies', 'normal blood pressure', 'high insulin'],
#  ['low pregnancies', 'high blood pressure', 'low insulin'],
#  ['low pregnancies', 'high blood pressure', 'normal insulin'],
#  ['low pregnancies', 'high blood pressure', 'high insulin'],
#  ['normal pregnancies', 'low blood pressure', 'low insulin'],
#  ['normal pregnancies', 'low blood pressure', 'normal insulin'],
#  ['normal pregnancies', 'low blood pressure', 'high insulin'],
#  ['normal pregnancies', 'normal blood pressure', 'low insulin'],
#  ['normal pregnancies', 'normal blood pressure', 'normal insulin'],
#  ['normal pregnancies', 'normal blood pressure', 'high insulin'],
#  ['normal pregnancies', 'high blood pressure', 'low insulin'],
#  ['normal pregnancies', 'high blood pressure', 'normal insulin'],
#  ['normal pregnancies', 'high blood pressure', 'high insulin'],
#  ['high pregnancies', 'low blood pressure', 'low insulin'],
#  ['high pregnancies', 'low blood pressure', 'normal insulin'],
#  ['high pregnancies', 'low blood pressure', 'high insulin'],
#  ['high pregnancies', 'normal blood pressure', 'low insulin'],
#  ['high pregnancies', 'normal blood pressure', 'normal insulin'],
#  ['high pregnancies', 'normal blood pressure', 'high insulin'],
#  ['high pregnancies', 'high blood pressure', 'low insulin'],
#  ['high pregnancies', 'high blood pressure', 'normal insulin'],
#  ['high pregnancies', 'high blood pressure', 'high insulin'],
#  ['low pregnancies', 'low blood pressure', 'low bmi'],
#  ['low pregnancies', 'low blood pressure', 'normal bmi'],
#  ['low pregnancies', 'low blood pressure', 'high bmi'],
#  ['low pregnancies', 'normal blood pressure', 'low bmi'],
#  ['low pregnancies', 'normal blood pressure', 'normal bmi'],
#  ['low pregnancies', 'normal blood pressure', 'high bmi'],
#  ['low pregnancies', 'high blood pressure', 'low bmi'],
#  ['low pregnancies', 'high blood pressure', 'normal bmi'],
#  ['low pregnancies', 'high blood pressure', 'high bmi'],
#  ['normal pregnancies', 'low blood pressure', 'low bmi'],
#  ['normal pregnancies', 'low blood pressure', 'normal bmi'],
#  ['normal pregnancies', 'low blood pressure', 'high bmi'],
#  ['normal pregnancies', 'normal blood pressure', 'low bmi'],
#  ['normal pregnancies', 'normal blood pressure', 'normal bmi'],
#  ['normal pregnancies', 'normal blood pressure', 'high bmi'],
#  ['normal pregnancies', 'high blood pressure', 'low bmi'],
#  ['normal pregnancies', 'high blood pressure', 'normal bmi'],
#  ['normal pregnancies', 'high blood pressure', 'high bmi'],
#  ['high pregnancies', 'low blood pressure', 'low bmi'],
#  ['high pregnancies', 'low blood pressure', 'normal bmi'],
#  ['high pregnancies', 'low blood pressure', 'high bmi'],
#  ['high pregnancies', 'normal blood pressure', 'low bmi'],
#  ['high pregnancies', 'normal blood pressure', 'normal bmi'],
#  ['high pregnancies', 'normal blood pressure', 'high bmi'],
#  ['high pregnancies', 'high blood pressure', 'low bmi'],
#  ['high pregnancies', 'high blood pressure', 'normal bmi'],
#  ['high pregnancies', 'high blood pressure', 'high bmi'],
#  ['low pregnancies', 'low blood pressure', 'low diabetes pedigree function'],
#  ['low pregnancies',
#   'low blood pressure',
#   'normal diabetes pedigree function'],
#  ['low pregnancies', 'low blood pressure', 'high diabetes pedigree function'],
#  ['low pregnancies',
#   'normal blood pressure',
#   'low diabetes pedigree function'],
#  ['low pregnancies',
#   'normal blood pressure',
#   'normal diabetes pedigree function'],
#  ['low pregnancies',
#   'normal blood pressure',
#   'high diabetes pedigree function'],
#  ['low pregnancies', 'high blood pressure', 'low diabetes pedigree function'],
#  ['low pregnancies',
#   'high blood pressure',
#   'normal diabetes pedigree function'],
#  ['low pregnancies', 'high blood pressure', 'high diabetes pedigree function'],
#  ['normal pregnancies',
#   'low blood pressure',
#   'low diabetes pedigree function'],
#  ['normal pregnancies',
#   'low blood pressure',
#   'normal diabetes pedigree function'],
#  ['normal pregnancies',
#   'low blood pressure',
#   'high diabetes pedigree function'],
#  ['normal pregnancies',
#   'normal blood pressure',
#   'low diabetes pedigree function'],
#  ['normal pregnancies',
#   'normal blood pressure',
#   'normal diabetes pedigree function'],
#  ['normal pregnancies',
#   'normal blood pressure',
#   'high diabetes pedigree function'],
#  ['normal pregnancies',
#   'high blood pressure',
#   'low diabetes pedigree function'],
#  ['normal pregnancies',
#   'high blood pressure',
#   'normal diabetes pedigree function'],
#  ['normal pregnancies',
#   'high blood pressure',
#   'high diabetes pedigree function'],
#  ['high pregnancies', 'low blood pressure', 'low diabetes pedigree function'],
#  ['high pregnancies',
#   'low blood pressure',
#   'normal diabetes pedigree function'],
#  ['high pregnancies', 'low blood pressure', 'high diabetes pedigree function'],
#  ['high pregnancies',
#   'normal blood pressure',
#   'low diabetes pedigree function'],
#  ['high pregnancies',
#   'normal blood pressure',
#   'normal diabetes pedigree function'],
#  ['high pregnancies',
#   'normal blood pressure',
#   'high diabetes pedigree function'],
#  ['high pregnancies', 'high blood pressure', 'low diabetes pedigree function'],
#  ['high pregnancies',
#   'high blood pressure',
#   'normal diabetes pedigree function'],
#  ['high pregnancies',
#   'high blood pressure',
#   'high diabetes pedigree function'],
#  ['low pregnancies', 'low blood pressure', 'low age'],
#  ['low pregnancies', 'low blood pressure', 'normal age'],
#  ['low pregnancies', 'low blood pressure', 'high age'],
#  ['low pregnancies', 'normal blood pressure', 'low age'],
#  ['low pregnancies', 'normal blood pressure', 'normal age'],
#  ['low pregnancies', 'normal blood pressure', 'high age'],
#  ['low pregnancies', 'high blood pressure', 'low age'],
#  ['low pregnancies', 'high blood pressure', 'normal age'],
#  ['low pregnancies', 'high blood pressure', 'high age'],
#  ['normal pregnancies', 'low blood pressure', 'low age'],
#  ['normal pregnancies', 'low blood pressure', 'normal age'],
#  ['normal pregnancies', 'low blood pressure', 'high age'],
#  ['normal pregnancies', 'normal blood pressure', 'low age'],
#  ['normal pregnancies', 'normal blood pressure', 'normal age'],
#  ['normal pregnancies', 'normal blood pressure', 'high age'],
#  ['normal pregnancies', 'high blood pressure', 'low age'],
#  ['normal pregnancies', 'high blood pressure', 'normal age'],
#  ['normal pregnancies', 'high blood pressure', 'high age'],
#  ['high pregnancies', 'low blood pressure', 'low age'],
#  ['high pregnancies', 'low blood pressure', 'normal age'],
#  ['high pregnancies', 'low blood pressure', 'high age'],
#  ['high pregnancies', 'normal blood pressure', 'low age'],
#  ['high pregnancies', 'normal blood pressure', 'normal age'],
#  ['high pregnancies', 'normal blood pressure', 'high age'],
#  ['high pregnancies', 'high blood pressure', 'low age'],
#  ['high pregnancies', 'high blood pressure', 'normal age'],
#  ['high pregnancies', 'high blood pressure', 'high age'],
#  ['low pregnancies', 'low skin thickness', 'low insulin'],
#  ['low pregnancies', 'low skin thickness', 'normal insulin'],
#  ['low pregnancies', 'low skin thickness', 'high insulin'],
#  ['low pregnancies', 'normal skin thickness', 'low insulin'],
#  ['low pregnancies', 'normal skin thickness', 'normal insulin'],
#  ['low pregnancies', 'normal skin thickness', 'high insulin'],
#  ['low pregnancies', 'high skin thickness', 'low insulin'],
#  ['low pregnancies', 'high skin thickness', 'normal insulin'],
#  ['low pregnancies', 'high skin thickness', 'high insulin'],
#  ['normal pregnancies', 'low skin thickness', 'low insulin'],
#  ['normal pregnancies', 'low skin thickness', 'normal insulin'],
#  ['normal pregnancies', 'low skin thickness', 'high insulin'],
#  ['normal pregnancies', 'normal skin thickness', 'low insulin'],
#  ['normal pregnancies', 'normal skin thickness', 'normal insulin'],
#  ['normal pregnancies', 'normal skin thickness', 'high insulin'],
#  ['normal pregnancies', 'high skin thickness', 'low insulin'],
#  ['normal pregnancies', 'high skin thickness', 'normal insulin'],
#  ['normal pregnancies', 'high skin thickness', 'high insulin'],
#  ['high pregnancies', 'low skin thickness', 'low insulin'],
#  ['high pregnancies', 'low skin thickness', 'normal insulin'],
#  ['high pregnancies', 'low skin thickness', 'high insulin'],
#  ['high pregnancies', 'normal skin thickness', 'low insulin'],
#  ['high pregnancies', 'normal skin thickness', 'normal insulin'],
#  ['high pregnancies', 'normal skin thickness', 'high insulin'],
#  ['high pregnancies', 'high skin thickness', 'low insulin'],
#  ['high pregnancies', 'high skin thickness', 'normal insulin'],
#  ['high pregnancies', 'high skin thickness', 'high insulin'],
#  ['low pregnancies', 'low skin thickness', 'low bmi'],
#  ['low pregnancies', 'low skin thickness', 'normal bmi'],
#  ['low pregnancies', 'low skin thickness', 'high bmi'],
#  ['low pregnancies', 'normal skin thickness', 'low bmi'],
#  ['low pregnancies', 'normal skin thickness', 'normal bmi'],
#  ['low pregnancies', 'normal skin thickness', 'high bmi'],
#  ['low pregnancies', 'high skin thickness', 'low bmi'],
#  ['low pregnancies', 'high skin thickness', 'normal bmi'],
#  ['low pregnancies', 'high skin thickness', 'high bmi'],
#  ['normal pregnancies', 'low skin thickness', 'low bmi'],
#  ['normal pregnancies', 'low skin thickness', 'normal bmi'],
#  ['normal pregnancies', 'low skin thickness', 'high bmi'],
#  ['normal pregnancies', 'normal skin thickness', 'low bmi'],
#  ['normal pregnancies', 'normal skin thickness', 'normal bmi'],
#  ['normal pregnancies', 'normal skin thickness', 'high bmi'],
#  ['normal pregnancies', 'high skin thickness', 'low bmi'],
#  ['normal pregnancies', 'high skin thickness', 'normal bmi'],
#  ['normal pregnancies', 'high skin thickness', 'high bmi'],
#  ['high pregnancies', 'low skin thickness', 'low bmi'],
#  ['high pregnancies', 'low skin thickness', 'normal bmi'],
#  ['high pregnancies', 'low skin thickness', 'high bmi'],
#  ['high pregnancies', 'normal skin thickness', 'low bmi'],
#  ['high pregnancies', 'normal skin thickness', 'normal bmi'],
#  ['high pregnancies', 'normal skin thickness', 'high bmi'],
#  ['high pregnancies', 'high skin thickness', 'low bmi'],
#  ['high pregnancies', 'high skin thickness', 'normal bmi'],
#  ['high pregnancies', 'high skin thickness', 'high bmi'],
#  ['low pregnancies', 'low skin thickness', 'low diabetes pedigree function'],
#  ['low pregnancies',
#   'low skin thickness',
#   'normal diabetes pedigree function'],
#  ['low pregnancies', 'low skin thickness', 'high diabetes pedigree function'],
#  ['low pregnancies',
#   'normal skin thickness',
#   'low diabetes pedigree function'],
#  ['low pregnancies',
#   'normal skin thickness',
#   'normal diabetes pedigree function'],
#  ['low pregnancies',
#   'normal skin thickness',
#   'high diabetes pedigree function'],
#  ['low pregnancies', 'high skin thickness', 'low diabetes pedigree function'],
#  ['low pregnancies',
#   'high skin thickness',
#   'normal diabetes pedigree function'],
#  ['low pregnancies', 'high skin thickness', 'high diabetes pedigree function'],
#  ['normal pregnancies',
#   'low skin thickness',
#   'low diabetes pedigree function'],
#  ['normal pregnancies',
#   'low skin thickness',
#   'normal diabetes pedigree function'],
#  ['normal pregnancies',
#   'low skin thickness',
#   'high diabetes pedigree function'],
#  ['normal pregnancies',
#   'normal skin thickness',
#   'low diabetes pedigree function'],
#  ['normal pregnancies',
#   'normal skin thickness',
#   'normal diabetes pedigree function'],
#  ['normal pregnancies',
#   'normal skin thickness',
#   'high diabetes pedigree function'],
#  ['normal pregnancies',
#   'high skin thickness',
#   'low diabetes pedigree function'],
#  ['normal pregnancies',
#   'high skin thickness',
#   'normal diabetes pedigree function'],
#  ['normal pregnancies',
#   'high skin thickness',
#   'high diabetes pedigree function'],
#  ['high pregnancies', 'low skin thickness', 'low diabetes pedigree function'],
#  ['high pregnancies',
#   'low skin thickness',
#   'normal diabetes pedigree function'],
#  ['high pregnancies', 'low skin thickness', 'high diabetes pedigree function'],
#  ['high pregnancies',
#   'normal skin thickness',
#   'low diabetes pedigree function'],
#  ['high pregnancies',
#   'normal skin thickness',
#   'normal diabetes pedigree function'],
#  ['high pregnancies',
#   'normal skin thickness',
#   'high diabetes pedigree function'],
#  ['high pregnancies', 'high skin thickness', 'low diabetes pedigree function'],
#  ['high pregnancies',
#   'high skin thickness',
#   'normal diabetes pedigree function'],
#  ['high pregnancies',
#   'high skin thickness',
#   'high diabetes pedigree function'],
#  ['low pregnancies', 'low skin thickness', 'low age'],
#  ['low pregnancies', 'low skin thickness', 'normal age'],
#  ['low pregnancies', 'low skin thickness', 'high age'],
#  ['low pregnancies', 'normal skin thickness', 'low age'],
#  ['low pregnancies', 'normal skin thickness', 'normal age'],
#  ['low pregnancies', 'normal skin thickness', 'high age'],
#  ['low pregnancies', 'high skin thickness', 'low age'],
#  ['low pregnancies', 'high skin thickness', 'normal age'],
#  ['low pregnancies', 'high skin thickness', 'high age'],
#  ['normal pregnancies', 'low skin thickness', 'low age'],
#  ['normal pregnancies', 'low skin thickness', 'normal age'],
#  ['normal pregnancies', 'low skin thickness', 'high age'],
#  ['normal pregnancies', 'normal skin thickness', 'low age'],
#  ['normal pregnancies', 'normal skin thickness', 'normal age'],
#  ['normal pregnancies', 'normal skin thickness', 'high age'],
#  ['normal pregnancies', 'high skin thickness', 'low age'],
#  ['normal pregnancies', 'high skin thickness', 'normal age'],
#  ['normal pregnancies', 'high skin thickness', 'high age'],
#  ['high pregnancies', 'low skin thickness', 'low age'],
#  ['high pregnancies', 'low skin thickness', 'normal age'],
#  ['high pregnancies', 'low skin thickness', 'high age'],
#  ['high pregnancies', 'normal skin thickness', 'low age'],
#  ['high pregnancies', 'normal skin thickness', 'normal age'],
#  ['high pregnancies', 'normal skin thickness', 'high age'],
#  ['high pregnancies', 'high skin thickness', 'low age'],
#  ['high pregnancies', 'high skin thickness', 'normal age'],
#  ['high pregnancies', 'high skin thickness', 'high age'],
#  ['low pregnancies', 'low insulin', 'low bmi'],
#  ['low pregnancies', 'low insulin', 'normal bmi'],
#  ['low pregnancies', 'low insulin', 'high bmi'],
#  ['low pregnancies', 'normal insulin', 'low bmi'],
#  ['low pregnancies', 'normal insulin', 'normal bmi'],
#  ['low pregnancies', 'normal insulin', 'high bmi'],
#  ['low pregnancies', 'high insulin', 'low bmi'],
#  ['low pregnancies', 'high insulin', 'normal bmi'],
#  ['low pregnancies', 'high insulin', 'high bmi'],
#  ['normal pregnancies', 'low insulin', 'low bmi'],
#  ['normal pregnancies', 'low insulin', 'normal bmi'],
#  ['normal pregnancies', 'low insulin', 'high bmi'],
#  ['normal pregnancies', 'normal insulin', 'low bmi'],
#  ['normal pregnancies', 'normal insulin', 'normal bmi'],
#  ['normal pregnancies', 'normal insulin', 'high bmi'],
#  ['normal pregnancies', 'high insulin', 'low bmi'],
#  ['normal pregnancies', 'high insulin', 'normal bmi'],
#  ['normal pregnancies', 'high insulin', 'high bmi'],
#  ['high pregnancies', 'low insulin', 'low bmi'],
#  ['high pregnancies', 'low insulin', 'normal bmi'],
#  ['high pregnancies', 'low insulin', 'high bmi'],
#  ['high pregnancies', 'normal insulin', 'low bmi'],
#  ['high pregnancies', 'normal insulin', 'normal bmi'],
#  ['high pregnancies', 'normal insulin', 'high bmi'],
#  ['high pregnancies', 'high insulin', 'low bmi'],
#  ['high pregnancies', 'high insulin', 'normal bmi'],
#  ['high pregnancies', 'high insulin', 'high bmi'],
#  ['low pregnancies', 'low insulin', 'low diabetes pedigree function'],
#  ['low pregnancies', 'low insulin', 'normal diabetes pedigree function'],
#  ['low pregnancies', 'low insulin', 'high diabetes pedigree function'],
#  ['low pregnancies', 'normal insulin', 'low diabetes pedigree function'],
#  ['low pregnancies', 'normal insulin', 'normal diabetes pedigree function'],
#  ['low pregnancies', 'normal insulin', 'high diabetes pedigree function'],
#  ['low pregnancies', 'high insulin', 'low diabetes pedigree function'],
#  ['low pregnancies', 'high insulin', 'normal diabetes pedigree function'],
#  ['low pregnancies', 'high insulin', 'high diabetes pedigree function'],
#  ['normal pregnancies', 'low insulin', 'low diabetes pedigree function'],
#  ['normal pregnancies', 'low insulin', 'normal diabetes pedigree function'],
#  ['normal pregnancies', 'low insulin', 'high diabetes pedigree function'],
#  ['normal pregnancies', 'normal insulin', 'low diabetes pedigree function'],
#  ['normal pregnancies', 'normal insulin', 'normal diabetes pedigree function'],
#  ['normal pregnancies', 'normal insulin', 'high diabetes pedigree function'],
#  ['normal pregnancies', 'high insulin', 'low diabetes pedigree function'],
#  ['normal pregnancies', 'high insulin', 'normal diabetes pedigree function'],
#  ['normal pregnancies', 'high insulin', 'high diabetes pedigree function'],
#  ['high pregnancies', 'low insulin', 'low diabetes pedigree function'],
#  ['high pregnancies', 'low insulin', 'normal diabetes pedigree function'],
#  ['high pregnancies', 'low insulin', 'high diabetes pedigree function'],
#  ['high pregnancies', 'normal insulin', 'low diabetes pedigree function'],
#  ['high pregnancies', 'normal insulin', 'normal diabetes pedigree function'],
#  ['high pregnancies', 'normal insulin', 'high diabetes pedigree function'],
#  ['high pregnancies', 'high insulin', 'low diabetes pedigree function'],
#  ['high pregnancies', 'high insulin', 'normal diabetes pedigree function'],
#  ['high pregnancies', 'high insulin', 'high diabetes pedigree function'],
#  ['low pregnancies', 'low insulin', 'low age'],
#  ['low pregnancies', 'low insulin', 'normal age'],
#  ['low pregnancies', 'low insulin', 'high age'],
#  ['low pregnancies', 'normal insulin', 'low age'],
#  ['low pregnancies', 'normal insulin', 'normal age'],
#  ['low pregnancies', 'normal insulin', 'high age'],
#  ['low pregnancies', 'high insulin', 'low age'],
#  ['low pregnancies', 'high insulin', 'normal age'],
#  ['low pregnancies', 'high insulin', 'high age'],
#  ['normal pregnancies', 'low insulin', 'low age'],
#  ['normal pregnancies', 'low insulin', 'normal age'],
#  ['normal pregnancies', 'low insulin', 'high age'],
#  ['normal pregnancies', 'normal insulin', 'low age'],
#  ['normal pregnancies', 'normal insulin', 'normal age'],
#  ['normal pregnancies', 'normal insulin', 'high age'],
#  ['normal pregnancies', 'high insulin', 'low age'],
#  ['normal pregnancies', 'high insulin', 'normal age'],
#  ['normal pregnancies', 'high insulin', 'high age'],
#  ['high pregnancies', 'low insulin', 'low age'],
#  ['high pregnancies', 'low insulin', 'normal age'],
#  ['high pregnancies', 'low insulin', 'high age'],
#  ['high pregnancies', 'normal insulin', 'low age'],
#  ['high pregnancies', 'normal insulin', 'normal age'],
#  ['high pregnancies', 'normal insulin', 'high age'],
#  ['high pregnancies', 'high insulin', 'low age'],
#  ['high pregnancies', 'high insulin', 'normal age'],
#  ['high pregnancies', 'high insulin', 'high age'],
#  ['low pregnancies', 'low bmi', 'low diabetes pedigree function'],
#  ['low pregnancies', 'low bmi', 'normal diabetes pedigree function'],
#  ['low pregnancies', 'low bmi', 'high diabetes pedigree function'],
#  ['low pregnancies', 'normal bmi', 'low diabetes pedigree function'],
#  ['low pregnancies', 'normal bmi', 'normal diabetes pedigree function'],
#  ['low pregnancies', 'normal bmi', 'high diabetes pedigree function'],
#  ['low pregnancies', 'high bmi', 'low diabetes pedigree function'],
#  ['low pregnancies', 'high bmi', 'normal diabetes pedigree function'],
#  ['low pregnancies', 'high bmi', 'high diabetes pedigree function'],
#  ['normal pregnancies', 'low bmi', 'low diabetes pedigree function'],
#  ['normal pregnancies', 'low bmi', 'normal diabetes pedigree function'],
#  ['normal pregnancies', 'low bmi', 'high diabetes pedigree function'],
#  ['normal pregnancies', 'normal bmi', 'low diabetes pedigree function'],
#  ['normal pregnancies', 'normal bmi', 'normal diabetes pedigree function'],
#  ['normal pregnancies', 'normal bmi', 'high diabetes pedigree function'],
#  ['normal pregnancies', 'high bmi', 'low diabetes pedigree function'],
#  ['normal pregnancies', 'high bmi', 'normal diabetes pedigree function'],
#  ['normal pregnancies', 'high bmi', 'high diabetes pedigree function'],
#  ['high pregnancies', 'low bmi', 'low diabetes pedigree function'],
#  ['high pregnancies', 'low bmi', 'normal diabetes pedigree function'],
#  ['high pregnancies', 'low bmi', 'high diabetes pedigree function'],
#  ['high pregnancies', 'normal bmi', 'low diabetes pedigree function'],
#  ['high pregnancies', 'normal bmi', 'normal diabetes pedigree function'],
#  ['high pregnancies', 'normal bmi', 'high diabetes pedigree function'],
#  ['high pregnancies', 'high bmi', 'low diabetes pedigree function'],
#  ['high pregnancies', 'high bmi', 'normal diabetes pedigree function'],
#  ['high pregnancies', 'high bmi', 'high diabetes pedigree function'],
#  ['low pregnancies', 'low bmi', 'low age'],
#  ['low pregnancies', 'low bmi', 'normal age'],
#  ['low pregnancies', 'low bmi', 'high age'],
#  ['low pregnancies', 'normal bmi', 'low age'],
#  ['low pregnancies', 'normal bmi', 'normal age'],
#  ['low pregnancies', 'normal bmi', 'high age'],
#  ['low pregnancies', 'high bmi', 'low age'],
#  ['low pregnancies', 'high bmi', 'normal age'],
#  ['low pregnancies', 'high bmi', 'high age'],
#  ['normal pregnancies', 'low bmi', 'low age'],
#  ['normal pregnancies', 'low bmi', 'normal age'],
#  ['normal pregnancies', 'low bmi', 'high age'],
#  ['normal pregnancies', 'normal bmi', 'low age'],
#  ['normal pregnancies', 'normal bmi', 'normal age'],
#  ['normal pregnancies', 'normal bmi', 'high age'],
#  ['normal pregnancies', 'high bmi', 'low age'],
#  ['normal pregnancies', 'high bmi', 'normal age'],
#  ['normal pregnancies', 'high bmi', 'high age'],
#  ['high pregnancies', 'low bmi', 'low age'],
#  ['high pregnancies', 'low bmi', 'normal age'],
#  ['high pregnancies', 'low bmi', 'high age'],
#  ['high pregnancies', 'normal bmi', 'low age'],
#  ['high pregnancies', 'normal bmi', 'normal age'],
#  ['high pregnancies', 'normal bmi', 'high age'],
#  ['high pregnancies', 'high bmi', 'low age'],
#  ['high pregnancies', 'high bmi', 'normal age'],
#  ['high pregnancies', 'high bmi', 'high age'],
#  ['low pregnancies', 'low diabetes pedigree function', 'low age'],
#  ['low pregnancies', 'low diabetes pedigree function', 'normal age'],
#  ['low pregnancies', 'low diabetes pedigree function', 'high age'],
#  ['low pregnancies', 'normal diabetes pedigree function', 'low age'],
#  ['low pregnancies', 'normal diabetes pedigree function', 'normal age'],
#  ['low pregnancies', 'normal diabetes pedigree function', 'high age'],
#  ['low pregnancies', 'high diabetes pedigree function', 'low age'],
#  ['low pregnancies', 'high diabetes pedigree function', 'normal age'],
#  ['low pregnancies', 'high diabetes pedigree function', 'high age'],
#  ['normal pregnancies', 'low diabetes pedigree function', 'low age'],
#  ['normal pregnancies', 'low diabetes pedigree function', 'normal age'],
#  ['normal pregnancies', 'low diabetes pedigree function', 'high age'],
#  ['normal pregnancies', 'normal diabetes pedigree function', 'low age'],
#  ['normal pregnancies', 'normal diabetes pedigree function', 'normal age'],
#  ['normal pregnancies', 'normal diabetes pedigree function', 'high age'],
#  ['normal pregnancies', 'high diabetes pedigree function', 'low age'],
#  ['normal pregnancies', 'high diabetes pedigree function', 'normal age'],
#  ['normal pregnancies', 'high diabetes pedigree function', 'high age'],
#  ['high pregnancies', 'low diabetes pedigree function', 'low age'],
#  ['high pregnancies', 'low diabetes pedigree function', 'normal age'],
#  ['high pregnancies', 'low diabetes pedigree function', 'high age'],
#  ['high pregnancies', 'normal diabetes pedigree function', 'low age'],
#  ['high pregnancies', 'normal diabetes pedigree function', 'normal age'],
#  ['high pregnancies', 'normal diabetes pedigree function', 'high age'],
#  ['high pregnancies', 'high diabetes pedigree function', 'low age'],
#  ['high pregnancies', 'high diabetes pedigree function', 'normal age'],
#  ['high pregnancies', 'high diabetes pedigree function', 'high age'],
#  ['low glucose', 'low blood pressure', 'low skin thickness'],
#  ['low glucose', 'low blood pressure', 'normal skin thickness'],
#  ['low glucose', 'low blood pressure', 'high skin thickness'],
#  ['low glucose', 'normal blood pressure', 'low skin thickness'],
#  ['low glucose', 'normal blood pressure', 'normal skin thickness'],
#  ['low glucose', 'normal blood pressure', 'high skin thickness'],
#  ['low glucose', 'high blood pressure', 'low skin thickness'],
#  ['low glucose', 'high blood pressure', 'normal skin thickness'],
#  ['low glucose', 'high blood pressure', 'high skin thickness'],
#  ['normal glucose', 'low blood pressure', 'low skin thickness'],
#  ['normal glucose', 'low blood pressure', 'normal skin thickness'],
#  ['normal glucose', 'low blood pressure', 'high skin thickness'],
#  ['normal glucose', 'normal blood pressure', 'low skin thickness'],
#  ['normal glucose', 'normal blood pressure', 'normal skin thickness'],
#  ['normal glucose', 'normal blood pressure', 'high skin thickness'],
#  ['normal glucose', 'high blood pressure', 'low skin thickness'],
#  ['normal glucose', 'high blood pressure', 'normal skin thickness'],
#  ['normal glucose', 'high blood pressure', 'high skin thickness'],
#  ['high glucose', 'low blood pressure', 'low skin thickness'],
#  ['high glucose', 'low blood pressure', 'normal skin thickness'],
#  ['high glucose', 'low blood pressure', 'high skin thickness'],
#  ['high glucose', 'normal blood pressure', 'low skin thickness'],
#  ['high glucose', 'normal blood pressure', 'normal skin thickness'],
#  ['high glucose', 'normal blood pressure', 'high skin thickness'],
#  ['high glucose', 'high blood pressure', 'low skin thickness'],
#  ['high glucose', 'high blood pressure', 'normal skin thickness'],
#  ['high glucose', 'high blood pressure', 'high skin thickness'],
#  ['low glucose', 'low blood pressure', 'low insulin'],
#  ['low glucose', 'low blood pressure', 'normal insulin'],
#  ['low glucose', 'low blood pressure', 'high insulin'],
#  ['low glucose', 'normal blood pressure', 'low insulin'],
#  ['low glucose', 'normal blood pressure', 'normal insulin'],
#  ['low glucose', 'normal blood pressure', 'high insulin'],
#  ['low glucose', 'high blood pressure', 'low insulin'],
#  ['low glucose', 'high blood pressure', 'normal insulin'],
#  ['low glucose', 'high blood pressure', 'high insulin'],
#  ['normal glucose', 'low blood pressure', 'low insulin'],
#  ['normal glucose', 'low blood pressure', 'normal insulin'],
#  ['normal glucose', 'low blood pressure', 'high insulin'],
#  ['normal glucose', 'normal blood pressure', 'low insulin'],
#  ['normal glucose', 'normal blood pressure', 'normal insulin'],
#  ['normal glucose', 'normal blood pressure', 'high insulin'],
#  ['normal glucose', 'high blood pressure', 'low insulin'],
#  ['normal glucose', 'high blood pressure', 'normal insulin'],
#  ['normal glucose', 'high blood pressure', 'high insulin'],
#  ['high glucose', 'low blood pressure', 'low insulin'],
#  ['high glucose', 'low blood pressure', 'normal insulin'],
#  ['high glucose', 'low blood pressure', 'high insulin'],
#  ['high glucose', 'normal blood pressure', 'low insulin'],
#  ['high glucose', 'normal blood pressure', 'normal insulin'],
#  ['high glucose', 'normal blood pressure', 'high insulin'],
#  ['high glucose', 'high blood pressure', 'low insulin'],
#  ['high glucose', 'high blood pressure', 'normal insulin'],
#  ['high glucose', 'high blood pressure', 'high insulin'],
#  ['low glucose', 'low blood pressure', 'low bmi'],
#  ['low glucose', 'low blood pressure', 'normal bmi'],
#  ['low glucose', 'low blood pressure', 'high bmi'],
#  ['low glucose', 'normal blood pressure', 'low bmi'],
#  ['low glucose', 'normal blood pressure', 'normal bmi'],
#  ['low glucose', 'normal blood pressure', 'high bmi'],
#  ['low glucose', 'high blood pressure', 'low bmi'],
#  ['low glucose', 'high blood pressure', 'normal bmi'],
#  ['low glucose', 'high blood pressure', 'high bmi'],
#  ['normal glucose', 'low blood pressure', 'low bmi'],
#  ['normal glucose', 'low blood pressure', 'normal bmi'],
#  ['normal glucose', 'low blood pressure', 'high bmi'],
#  ['normal glucose', 'normal blood pressure', 'low bmi'],
#  ['normal glucose', 'normal blood pressure', 'normal bmi'],
#  ['normal glucose', 'normal blood pressure', 'high bmi'],
#  ['normal glucose', 'high blood pressure', 'low bmi'],
#  ['normal glucose', 'high blood pressure', 'normal bmi'],
#  ['normal glucose', 'high blood pressure', 'high bmi'],
#  ['high glucose', 'low blood pressure', 'low bmi'],
#  ['high glucose', 'low blood pressure', 'normal bmi'],
#  ['high glucose', 'low blood pressure', 'high bmi'],
#  ['high glucose', 'normal blood pressure', 'low bmi'],
#  ['high glucose', 'normal blood pressure', 'normal bmi'],
#  ['high glucose', 'normal blood pressure', 'high bmi'],
#  ['high glucose', 'high blood pressure', 'low bmi'],
#  ['high glucose', 'high blood pressure', 'normal bmi'],
#  ['high glucose', 'high blood pressure', 'high bmi'],
#  ['low glucose', 'low blood pressure', 'low diabetes pedigree function'],
#  ['low glucose', 'low blood pressure', 'normal diabetes pedigree function'],
#  ['low glucose', 'low blood pressure', 'high diabetes pedigree function'],
#  ['low glucose', 'normal blood pressure', 'low diabetes pedigree function'],
#  ['low glucose', 'normal blood pressure', 'normal diabetes pedigree function'],
#  ['low glucose', 'normal blood pressure', 'high diabetes pedigree function'],
#  ['low glucose', 'high blood pressure', 'low diabetes pedigree function'],
#  ['low glucose', 'high blood pressure', 'normal diabetes pedigree function'],
#  ['low glucose', 'high blood pressure', 'high diabetes pedigree function'],
#  ['normal glucose', 'low blood pressure', 'low diabetes pedigree function'],
#  ['normal glucose', 'low blood pressure', 'normal diabetes pedigree function'],
#  ['normal glucose', 'low blood pressure', 'high diabetes pedigree function'],
#  ['normal glucose', 'normal blood pressure', 'low diabetes pedigree function'],
#  ['normal glucose',
#   'normal blood pressure',
#   'normal diabetes pedigree function'],
#  ['normal glucose',
#   'normal blood pressure',
#   'high diabetes pedigree function'],
#  ['normal glucose', 'high blood pressure', 'low diabetes pedigree function'],
#  ['normal glucose',
#   'high blood pressure',
#   'normal diabetes pedigree function'],
#  ['normal glucose', 'high blood pressure', 'high diabetes pedigree function'],
#  ['high glucose', 'low blood pressure', 'low diabetes pedigree function'],
#  ['high glucose', 'low blood pressure', 'normal diabetes pedigree function'],
#  ['high glucose', 'low blood pressure', 'high diabetes pedigree function'],
#  ['high glucose', 'normal blood pressure', 'low diabetes pedigree function'],
#  ['high glucose',
#   'normal blood pressure',
#   'normal diabetes pedigree function'],
#  ['high glucose', 'normal blood pressure', 'high diabetes pedigree function'],
#  ['high glucose', 'high blood pressure', 'low diabetes pedigree function'],
#  ['high glucose', 'high blood pressure', 'normal diabetes pedigree function'],
#  ['high glucose', 'high blood pressure', 'high diabetes pedigree function'],
#  ['low glucose', 'low blood pressure', 'low age'],
#  ['low glucose', 'low blood pressure', 'normal age'],
#  ['low glucose', 'low blood pressure', 'high age'],
#  ['low glucose', 'normal blood pressure', 'low age'],
#  ['low glucose', 'normal blood pressure', 'normal age'],
#  ['low glucose', 'normal blood pressure', 'high age'],
#  ['low glucose', 'high blood pressure', 'low age'],
#  ['low glucose', 'high blood pressure', 'normal age'],
#  ['low glucose', 'high blood pressure', 'high age'],
#  ['normal glucose', 'low blood pressure', 'low age'],
#  ['normal glucose', 'low blood pressure', 'normal age'],
#  ['normal glucose', 'low blood pressure', 'high age'],
#  ['normal glucose', 'normal blood pressure', 'low age'],
#  ['normal glucose', 'normal blood pressure', 'normal age'],
#  ['normal glucose', 'normal blood pressure', 'high age'],
#  ['normal glucose', 'high blood pressure', 'low age'],
#  ['normal glucose', 'high blood pressure', 'normal age'],
#  ['normal glucose', 'high blood pressure', 'high age'],
#  ['high glucose', 'low blood pressure', 'low age'],
#  ['high glucose', 'low blood pressure', 'normal age'],
#  ['high glucose', 'low blood pressure', 'high age'],
#  ['high glucose', 'normal blood pressure', 'low age'],
#  ['high glucose', 'normal blood pressure', 'normal age'],
#  ['high glucose', 'normal blood pressure', 'high age'],
#  ['high glucose', 'high blood pressure', 'low age'],
#  ['high glucose', 'high blood pressure', 'normal age'],
#  ['high glucose', 'high blood pressure', 'high age'],
#  ['low glucose', 'low skin thickness', 'low insulin'],
#  ['low glucose', 'low skin thickness', 'normal insulin'],
#  ['low glucose', 'low skin thickness', 'high insulin'],
#  ['low glucose', 'normal skin thickness', 'low insulin'],
#  ['low glucose', 'normal skin thickness', 'normal insulin'],
#  ['low glucose', 'normal skin thickness', 'high insulin'],
#  ['low glucose', 'high skin thickness', 'low insulin'],
#  ['low glucose', 'high skin thickness', 'normal insulin'],
#  ['low glucose', 'high skin thickness', 'high insulin'],
#  ['normal glucose', 'low skin thickness', 'low insulin'],
#  ['normal glucose', 'low skin thickness', 'normal insulin'],
#  ['normal glucose', 'low skin thickness', 'high insulin'],
#  ['normal glucose', 'normal skin thickness', 'low insulin'],
#  ['normal glucose', 'normal skin thickness', 'normal insulin'],
#  ['normal glucose', 'normal skin thickness', 'high insulin'],
#  ['normal glucose', 'high skin thickness', 'low insulin'],
#  ['normal glucose', 'high skin thickness', 'normal insulin'],
#  ['normal glucose', 'high skin thickness', 'high insulin'],
#  ['high glucose', 'low skin thickness', 'low insulin'],
#  ['high glucose', 'low skin thickness', 'normal insulin'],
#  ['high glucose', 'low skin thickness', 'high insulin'],
#  ['high glucose', 'normal skin thickness', 'low insulin'],
#  ['high glucose', 'normal skin thickness', 'normal insulin'],
#  ['high glucose', 'normal skin thickness', 'high insulin'],
#  ['high glucose', 'high skin thickness', 'low insulin'],
#  ['high glucose', 'high skin thickness', 'normal insulin'],
#  ['high glucose', 'high skin thickness', 'high insulin'],
#  ['low glucose', 'low skin thickness', 'low bmi'],
#  ['low glucose', 'low skin thickness', 'normal bmi'],
#  ['low glucose', 'low skin thickness', 'high bmi'],
#  ['low glucose', 'normal skin thickness', 'low bmi'],
#  ['low glucose', 'normal skin thickness', 'normal bmi'],
#  ['low glucose', 'normal skin thickness', 'high bmi'],
#  ['low glucose', 'high skin thickness', 'low bmi'],
#  ['low glucose', 'high skin thickness', 'normal bmi'],
#  ['low glucose', 'high skin thickness', 'high bmi'],
#  ['normal glucose', 'low skin thickness', 'low bmi'],
#  ['normal glucose', 'low skin thickness', 'normal bmi'],
#  ['normal glucose', 'low skin thickness', 'high bmi'],
#  ['normal glucose', 'normal skin thickness', 'low bmi'],
#  ['normal glucose', 'normal skin thickness', 'normal bmi'],
#  ['normal glucose', 'normal skin thickness', 'high bmi'],
#  ['normal glucose', 'high skin thickness', 'low bmi'],
#  ['normal glucose', 'high skin thickness', 'normal bmi'],
#  ['normal glucose', 'high skin thickness', 'high bmi'],
#  ['high glucose', 'low skin thickness', 'low bmi'],
#  ['high glucose', 'low skin thickness', 'normal bmi'],
#  ['high glucose', 'low skin thickness', 'high bmi'],
#  ['high glucose', 'normal skin thickness', 'low bmi'],
#  ['high glucose', 'normal skin thickness', 'normal bmi'],
#  ['high glucose', 'normal skin thickness', 'high bmi'],
#  ['high glucose', 'high skin thickness', 'low bmi'],
#  ['high glucose', 'high skin thickness', 'normal bmi'],
#  ['high glucose', 'high skin thickness', 'high bmi'],
#  ['low glucose', 'low skin thickness', 'low diabetes pedigree function'],
#  ['low glucose', 'low skin thickness', 'normal diabetes pedigree function'],
#  ['low glucose', 'low skin thickness', 'high diabetes pedigree function'],
#  ['low glucose', 'normal skin thickness', 'low diabetes pedigree function'],
#  ['low glucose', 'normal skin thickness', 'normal diabetes pedigree function'],
#  ['low glucose', 'normal skin thickness', 'high diabetes pedigree function'],
#  ['low glucose', 'high skin thickness', 'low diabetes pedigree function'],
#  ['low glucose', 'high skin thickness', 'normal diabetes pedigree function'],
#  ['low glucose', 'high skin thickness', 'high diabetes pedigree function'],
#  ['normal glucose', 'low skin thickness', 'low diabetes pedigree function'],
#  ['normal glucose', 'low skin thickness', 'normal diabetes pedigree function'],
#  ['normal glucose', 'low skin thickness', 'high diabetes pedigree function'],
#  ['normal glucose', 'normal skin thickness', 'low diabetes pedigree function'],
#  ['normal glucose',
#   'normal skin thickness',
#   'normal diabetes pedigree function'],
#  ['normal glucose',
#   'normal skin thickness',
#   'high diabetes pedigree function'],
#  ['normal glucose', 'high skin thickness', 'low diabetes pedigree function'],
#  ['normal glucose',
#   'high skin thickness',
#   'normal diabetes pedigree function'],
#  ['normal glucose', 'high skin thickness', 'high diabetes pedigree function'],
#  ['high glucose', 'low skin thickness', 'low diabetes pedigree function'],
#  ['high glucose', 'low skin thickness', 'normal diabetes pedigree function'],
#  ['high glucose', 'low skin thickness', 'high diabetes pedigree function'],
#  ['high glucose', 'normal skin thickness', 'low diabetes pedigree function'],
#  ['high glucose',
#   'normal skin thickness',
#   'normal diabetes pedigree function'],
#  ['high glucose', 'normal skin thickness', 'high diabetes pedigree function'],
#  ['high glucose', 'high skin thickness', 'low diabetes pedigree function'],
#  ['high glucose', 'high skin thickness', 'normal diabetes pedigree function'],
#  ['high glucose', 'high skin thickness', 'high diabetes pedigree function'],
#  ['low glucose', 'low skin thickness', 'low age'],
#  ['low glucose', 'low skin thickness', 'normal age'],
#  ['low glucose', 'low skin thickness', 'high age'],
#  ['low glucose', 'normal skin thickness', 'low age'],
#  ['low glucose', 'normal skin thickness', 'normal age'],
#  ['low glucose', 'normal skin thickness', 'high age'],
#  ['low glucose', 'high skin thickness', 'low age'],
#  ['low glucose', 'high skin thickness', 'normal age'],
#  ['low glucose', 'high skin thickness', 'high age'],
#  ['normal glucose', 'low skin thickness', 'low age'],
#  ['normal glucose', 'low skin thickness', 'normal age'],
#  ['normal glucose', 'low skin thickness', 'high age'],
#  ['normal glucose', 'normal skin thickness', 'low age'],
#  ['normal glucose', 'normal skin thickness', 'normal age'],
#  ['normal glucose', 'normal skin thickness', 'high age'],
#  ['normal glucose', 'high skin thickness', 'low age'],
#  ['normal glucose', 'high skin thickness', 'normal age'],
#  ['normal glucose', 'high skin thickness', 'high age'],
#  ['high glucose', 'low skin thickness', 'low age'],
#  ['high glucose', 'low skin thickness', 'normal age'],
#  ['high glucose', 'low skin thickness', 'high age'],
#  ['high glucose', 'normal skin thickness', 'low age'],
#  ['high glucose', 'normal skin thickness', 'normal age'],
#  ['high glucose', 'normal skin thickness', 'high age'],
#  ['high glucose', 'high skin thickness', 'low age'],
#  ['high glucose', 'high skin thickness', 'normal age'],
#  ['high glucose', 'high skin thickness', 'high age'],
#  ['low glucose', 'low insulin', 'low bmi'],
#  ['low glucose', 'low insulin', 'normal bmi'],
#  ['low glucose', 'low insulin', 'high bmi'],
#  ['low glucose', 'normal insulin', 'low bmi'],
#  ['low glucose', 'normal insulin', 'normal bmi'],
#  ['low glucose', 'normal insulin', 'high bmi'],
#  ['low glucose', 'high insulin', 'low bmi'],
#  ['low glucose', 'high insulin', 'normal bmi'],
#  ['low glucose', 'high insulin', 'high bmi'],
#  ['normal glucose', 'low insulin', 'low bmi'],
#  ['normal glucose', 'low insulin', 'normal bmi'],
#  ['normal glucose', 'low insulin', 'high bmi'],
#  ['normal glucose', 'normal insulin', 'low bmi'],
#  ['normal glucose', 'normal insulin', 'normal bmi'],
#  ['normal glucose', 'normal insulin', 'high bmi'],
#  ['normal glucose', 'high insulin', 'low bmi'],
#  ['normal glucose', 'high insulin', 'normal bmi'],
#  ['normal glucose', 'high insulin', 'high bmi'],
#  ['high glucose', 'low insulin', 'low bmi'],
#  ['high glucose', 'low insulin', 'normal bmi'],
#  ['high glucose', 'low insulin', 'high bmi'],
#  ['high glucose', 'normal insulin', 'low bmi'],
#  ['high glucose', 'normal insulin', 'normal bmi'],
#  ['high glucose', 'normal insulin', 'high bmi'],
#  ['high glucose', 'high insulin', 'low bmi'],
#  ['high glucose', 'high insulin', 'normal bmi'],
#  ['high glucose', 'high insulin', 'high bmi'],
#  ['low glucose', 'low insulin', 'low diabetes pedigree function'],
#  ['low glucose', 'low insulin', 'normal diabetes pedigree function'],
#  ['low glucose', 'low insulin', 'high diabetes pedigree function'],
#  ['low glucose', 'normal insulin', 'low diabetes pedigree function'],
#  ['low glucose', 'normal insulin', 'normal diabetes pedigree function'],
#  ['low glucose', 'normal insulin', 'high diabetes pedigree function'],
#  ['low glucose', 'high insulin', 'low diabetes pedigree function'],
#  ['low glucose', 'high insulin', 'normal diabetes pedigree function'],
#  ['low glucose', 'high insulin', 'high diabetes pedigree function'],
#  ['normal glucose', 'low insulin', 'low diabetes pedigree function'],
#  ['normal glucose', 'low insulin', 'normal diabetes pedigree function'],
#  ['normal glucose', 'low insulin', 'high diabetes pedigree function'],
#  ['normal glucose', 'normal insulin', 'low diabetes pedigree function'],
#  ['normal glucose', 'normal insulin', 'normal diabetes pedigree function'],
#  ['normal glucose', 'normal insulin', 'high diabetes pedigree function'],
#  ['normal glucose', 'high insulin', 'low diabetes pedigree function'],
#  ['normal glucose', 'high insulin', 'normal diabetes pedigree function'],
#  ['normal glucose', 'high insulin', 'high diabetes pedigree function'],
#  ['high glucose', 'low insulin', 'low diabetes pedigree function'],
#  ['high glucose', 'low insulin', 'normal diabetes pedigree function'],
#  ['high glucose', 'low insulin', 'high diabetes pedigree function'],
#  ['high glucose', 'normal insulin', 'low diabetes pedigree function'],
#  ['high glucose', 'normal insulin', 'normal diabetes pedigree function'],
#  ['high glucose', 'normal insulin', 'high diabetes pedigree function'],
#  ['high glucose', 'high insulin', 'low diabetes pedigree function'],
#  ['high glucose', 'high insulin', 'normal diabetes pedigree function'],
#  ['high glucose', 'high insulin', 'high diabetes pedigree function'],
#  ['low glucose', 'low insulin', 'low age'],
#  ['low glucose', 'low insulin', 'normal age'],
#  ['low glucose', 'low insulin', 'high age'],
#  ['low glucose', 'normal insulin', 'low age'],
#  ['low glucose', 'normal insulin', 'normal age'],
#  ['low glucose', 'normal insulin', 'high age'],
#  ['low glucose', 'high insulin', 'low age'],
#  ['low glucose', 'high insulin', 'normal age'],
#  ['low glucose', 'high insulin', 'high age'],
#  ['normal glucose', 'low insulin', 'low age'],
#  ['normal glucose', 'low insulin', 'normal age'],
#  ['normal glucose', 'low insulin', 'high age'],
#  ['normal glucose', 'normal insulin', 'low age'],
#  ['normal glucose', 'normal insulin', 'normal age'],
#  ['normal glucose', 'normal insulin', 'high age'],
#  ['normal glucose', 'high insulin', 'low age'],
#  ['normal glucose', 'high insulin', 'normal age'],
#  ['normal glucose', 'high insulin', 'high age'],
#  ['high glucose', 'low insulin', 'low age'],
#  ['high glucose', 'low insulin', 'normal age'],
#  ['high glucose', 'low insulin', 'high age'],
#  ['high glucose', 'normal insulin', 'low age'],
#  ['high glucose', 'normal insulin', 'normal age'],
#  ['high glucose', 'normal insulin', 'high age'],
#  ['high glucose', 'high insulin', 'low age'],
#  ['high glucose', 'high insulin', 'normal age'],
#  ['high glucose', 'high insulin', 'high age'],
#  ['low glucose', 'low bmi', 'low diabetes pedigree function'],
#  ['low glucose', 'low bmi', 'normal diabetes pedigree function'],
#  ['low glucose', 'low bmi', 'high diabetes pedigree function'],
#  ['low glucose', 'normal bmi', 'low diabetes pedigree function'],
#  ['low glucose', 'normal bmi', 'normal diabetes pedigree function'],
#  ['low glucose', 'normal bmi', 'high diabetes pedigree function'],
#  ['low glucose', 'high bmi', 'low diabetes pedigree function'],
#  ['low glucose', 'high bmi', 'normal diabetes pedigree function'],
#  ['low glucose', 'high bmi', 'high diabetes pedigree function'],
#  ['normal glucose', 'low bmi', 'low diabetes pedigree function'],
#  ['normal glucose', 'low bmi', 'normal diabetes pedigree function'],
#  ['normal glucose', 'low bmi', 'high diabetes pedigree function'],
#  ['normal glucose', 'normal bmi', 'low diabetes pedigree function'],
#  ['normal glucose', 'normal bmi', 'normal diabetes pedigree function'],
#  ['normal glucose', 'normal bmi', 'high diabetes pedigree function'],
#  ['normal glucose', 'high bmi', 'low diabetes pedigree function'],
#  ['normal glucose', 'high bmi', 'normal diabetes pedigree function'],
#  ['normal glucose', 'high bmi', 'high diabetes pedigree function'],
#  ['high glucose', 'low bmi', 'low diabetes pedigree function'],
#  ['high glucose', 'low bmi', 'normal diabetes pedigree function'],
#  ['high glucose', 'low bmi', 'high diabetes pedigree function'],
#  ['high glucose', 'normal bmi', 'low diabetes pedigree function'],
#  ['high glucose', 'normal bmi', 'normal diabetes pedigree function'],
#  ['high glucose', 'normal bmi', 'high diabetes pedigree function'],
#  ['high glucose', 'high bmi', 'low diabetes pedigree function'],
#  ['high glucose', 'high bmi', 'normal diabetes pedigree function'],
#  ['high glucose', 'high bmi', 'high diabetes pedigree function'],
#  ['low glucose', 'low bmi', 'low age'],
#  ['low glucose', 'low bmi', 'normal age'],
#  ['low glucose', 'low bmi', 'high age'],
#  ['low glucose', 'normal bmi', 'low age'],
#  ['low glucose', 'normal bmi', 'normal age'],
#  ['low glucose', 'normal bmi', 'high age'],
#  ['low glucose', 'high bmi', 'low age'],
#  ['low glucose', 'high bmi', 'normal age'],
#  ['low glucose', 'high bmi', 'high age'],
#  ['normal glucose', 'low bmi', 'low age'],
#  ['normal glucose', 'low bmi', 'normal age'],
#  ['normal glucose', 'low bmi', 'high age'],
#  ['normal glucose', 'normal bmi', 'low age'],
#  ['normal glucose', 'normal bmi', 'normal age'],
#  ['normal glucose', 'normal bmi', 'high age'],
#  ['normal glucose', 'high bmi', 'low age'],
#  ['normal glucose', 'high bmi', 'normal age'],
#  ['normal glucose', 'high bmi', 'high age'],
#  ['high glucose', 'low bmi', 'low age'],
#  ['high glucose', 'low bmi', 'normal age'],
#  ['high glucose', 'low bmi', 'high age'],
#  ['high glucose', 'normal bmi', 'low age'],
#  ['high glucose', 'normal bmi', 'normal age'],
#  ['high glucose', 'normal bmi', 'high age'],
#  ['high glucose', 'high bmi', 'low age'],
#  ['high glucose', 'high bmi', 'normal age'],
#  ['high glucose', 'high bmi', 'high age'],
#  ['low glucose', 'low diabetes pedigree function', 'low age'],
#  ['low glucose', 'low diabetes pedigree function', 'normal age'],
#  ['low glucose', 'low diabetes pedigree function', 'high age'],
#  ['low glucose', 'normal diabetes pedigree function', 'low age'],
#  ['low glucose', 'normal diabetes pedigree function', 'normal age'],
#  ['low glucose', 'normal diabetes pedigree function', 'high age'],
#  ['low glucose', 'high diabetes pedigree function', 'low age'],
#  ['low glucose', 'high diabetes pedigree function', 'normal age'],
#  ['low glucose', 'high diabetes pedigree function', 'high age'],
#  ['normal glucose', 'low diabetes pedigree function', 'low age'],
#  ['normal glucose', 'low diabetes pedigree function', 'normal age'],
#  ['normal glucose', 'low diabetes pedigree function', 'high age'],
#  ['normal glucose', 'normal diabetes pedigree function', 'low age'],
#  ['normal glucose', 'normal diabetes pedigree function', 'normal age'],
#  ['normal glucose', 'normal diabetes pedigree function', 'high age'],
#  ['normal glucose', 'high diabetes pedigree function', 'low age'],
#  ['normal glucose', 'high diabetes pedigree function', 'normal age'],
#  ['normal glucose', 'high diabetes pedigree function', 'high age'],
#  ['high glucose', 'low diabetes pedigree function', 'low age'],
#  ['high glucose', 'low diabetes pedigree function', 'normal age'],
#  ['high glucose', 'low diabetes pedigree function', 'high age'],
#  ['high glucose', 'normal diabetes pedigree function', 'low age'],
#  ['high glucose', 'normal diabetes pedigree function', 'normal age'],
#  ['high glucose', 'normal diabetes pedigree function', 'high age'],
#  ['high glucose', 'high diabetes pedigree function', 'low age'],
#  ['high glucose', 'high diabetes pedigree function', 'normal age'],
#  ['high glucose', 'high diabetes pedigree function', 'high age'],
#  ['low blood pressure', 'low skin thickness', 'low insulin'],
#  ['low blood pressure', 'low skin thickness', 'normal insulin'],
#  ['low blood pressure', 'low skin thickness', 'high insulin'],
#  ['low blood pressure', 'normal skin thickness', 'low insulin'],
#  ['low blood pressure', 'normal skin thickness', 'normal insulin'],
#  ['low blood pressure', 'normal skin thickness', 'high insulin'],
#  ['low blood pressure', 'high skin thickness', 'low insulin'],
#  ['low blood pressure', 'high skin thickness', 'normal insulin'],
#  ['low blood pressure', 'high skin thickness', 'high insulin'],
#  ['normal blood pressure', 'low skin thickness', 'low insulin'],
#  ['normal blood pressure', 'low skin thickness', 'normal insulin'],
#  ['normal blood pressure', 'low skin thickness', 'high insulin'],
#  ['normal blood pressure', 'normal skin thickness', 'low insulin'],
#  ['normal blood pressure', 'normal skin thickness', 'normal insulin'],
#  ['normal blood pressure', 'normal skin thickness', 'high insulin'],
#  ['normal blood pressure', 'high skin thickness', 'low insulin'],
#  ['normal blood pressure', 'high skin thickness', 'normal insulin'],
#  ['normal blood pressure', 'high skin thickness', 'high insulin'],
#  ['high blood pressure', 'low skin thickness', 'low insulin'],
#  ['high blood pressure', 'low skin thickness', 'normal insulin'],
#  ['high blood pressure', 'low skin thickness', 'high insulin'],
#  ['high blood pressure', 'normal skin thickness', 'low insulin'],
#  ['high blood pressure', 'normal skin thickness', 'normal insulin'],
#  ['high blood pressure', 'normal skin thickness', 'high insulin'],
#  ['high blood pressure', 'high skin thickness', 'low insulin'],
#  ['high blood pressure', 'high skin thickness', 'normal insulin'],
#  ['high blood pressure', 'high skin thickness', 'high insulin'],
#  ['low blood pressure', 'low skin thickness', 'low bmi'],
#  ...]

# %%
#creates mimic sample with a specified SampleNumber of -1
driver.execute_query( 
    """
    Create(mimic:Sample {SampleNumber: -1})
    """

)

# %%
#get node id of mimic sample
nodeId = driver.execute_query(
    """
    Match (m:Sample) where m.SampleNumber=-1
    return id(m)
    """
)[0][0][0]

# %%
#removes all relationships for mimic
def clearrels():
    driver.execute_query(
        """
        match (n:Sample)-[r]->(m) where n.SampleNumber=-1 delete r
        """

    )

# %%
#creates specified relationship between mimic and other node
def createrels(relationship, node):
    query = f"""
    MATCH (n:Sample {{SampleNumber: -1}}), (m:medical_concept {{name: $nodename}})
    MERGE (n)-[r:{relationship}]->(m)
    """
    driver.execute_query(
        query,
        nodename=node
    )

# %%
#projects graph with passed in graphName
def createGraph(name):
    driver.execute_query(
        """
        CALL gds.graph.project(
            $graphName,
            {
                Sample: '*',
                medical_concept: '*',
                definition: '*',
                synonyms: '*'
            },
            {
                HAS_PREGNANCIES: {
                orientation: 'UNDIRECTED'  
                }, 
                HAS_GLUCOSE: {
                orientation: 'UNDIRECTED'  
                },
                HAS_BLOOD_PRESSURE: {
                orientation: 'UNDIRECTED'  
                },
                HAS_SKIN_THICKNESS: {
                orientation: 'UNDIRECTED'  
                },
                HAS_INSULIN: {
                orientation: 'UNDIRECTED'  
                }, 
                HAS_BMI: {
                orientation: 'UNDIRECTED'  
                },
                HAS_DIABETES_PEDIGREE_FUNCTION: {
                orientation: 'UNDIRECTED'  
                },
                HAS_AGE: {
                orientation: 'UNDIRECTED'  
                }, 
                Definition : {
                orientation: 'UNDIRECTED'  
                },
                Synonym: {
                orientation: 'UNDIRECTED'  
                },
                embedding_match_node: {
                orientation: 'UNDIRECTED'  
                }
            })
        """,
        graphName=name
    )

# %%
#gets fastrp embedding for mimic
def getembedding(gname):
    results = driver.execute_query(
        """
        CALL gds.fastRP.stream($graphName, {
            embeddingDimension: $embeddingDimension,
            randomSeed:42
        })
        YIELD nodeId, embedding
        WHERE nodeId = $nodeId
        return nodeId, embedding;
        """,
        embeddingDimension=128, graphName=gname, nodeId=nodeId
    )

    return results[0][0][1]

# %%
#loops through combination list and gets all embeddings for the mimic in a dictionary 
def getembeddingformimic(clist):
    retdict = {} #empty dictionary to hold all resulting embeddings
    for i,c in enumerate(clist):
       if i%10==0: #if divisible by 10, we delete all graphs in memory 
           clearGraphs()
       graphname = f"pima{i%10}"
       clearrels() #clear relationships
       for node in c: 
           relationship = relationships[node]
           createrels(relationship, node) #create relationship according to combination
       createGraph(graphname) #create graph
       embedding = getembedding(graphname)
       retdict[str(c)]= embedding #add resulting embedding and combination to dictionary
    
    return retdict

# %%
#main - applies conmbinations to graph and writes to file 
import csv 
for i in range(8):
    combinations = generate_combinations(fields_variations, i+1)
    embeddings = getembeddingformimic(combinations)
    with open("data/finalresults.csv", 'a', newline='') as file:
        writer = csv.writer(file)

        for key, value in embeddings.items():
            writer.writerow([key, value])
    clearGraphs()

# %%
clearGraphs()

# %%
clearrels()

# %% [markdown]
# ## Applying Embeeddings to Models

# %%
#load combinations and their embeddings 
embdf = pd.read_csv("data/finalresults.csv")
embdf.head()
# Out:
#             relationships                                          embedding
# 0     ['low pregnancies']  [0.3559499979019165, 0.017154032364487648, -0....
# 1  ['normal pregnancies']  [0.21517100930213928, 0.09962455183267593, 0.1...
# 2    ['high pregnancies']  [0.1451621651649475, 0.012034144252538681, -0....
# 3         ['low glucose']  [0.07380708307027817, 0.07721707224845886, 0.0...
# 4      ['normal glucose']  [0.4024839997291565, -0.0163387693464756, -0.0...

# %%
import ast
import joblib
embdf['embedding'] = embdf['embedding'].apply(ast.literal_eval) #convert embeddings to lists (instead of strings)

# %%
input = np.array(embdf['embedding'].tolist()) #aggregate embedding column

# %% [markdown]
# ### Random Forest

# %%
#load best rf model
with open('final_models/rfemb.pkl', 'rb') as file:
    model = joblib.load(file)

# %%
#predict
pred = model.predict(input)

# %%
#save prediction to embdf
embdf['score_rf'] = pred

# %% [markdown]
# ### XGBoost

# %%
#load best xgb model
with open('final_models/xgbemb.pkl', 'rb') as file:
    model = joblib.load(file)

# %%
#predict
pred = model.predict(input)

# %%
#save prediction to embdf
embdf['score_xgb'] = pred

# %% [markdown]
# ### SVM

# %%
#load best svm model
with open('final_models/svmemb.pkl', 'rb') as file:
    model = joblib.load(file)

# %%
#predict
pred = model.predict(input)

# %%
#save prediction to embdf
embdf['score_svm'] = pred

# %% [markdown]
# ### Naive Bayes

# %%
#load best nb model
with open('final_models/nbemb.pkl', 'rb') as file:
    model = joblib.load(file)

# %%
#predict
pred = model.predict(input)

# %%
#save prediction to embdf
embdf['score_nb'] = pred

# %% [markdown]
# ### Neural Networks

# %%
from tensorflow.keras.models import load_model

#load best nn model
model = load_model('final_models/nnemb.keras')

# %%
#predict
pred = model.predict(input)
# Out:
# 2048/2048 ━━━━━━━━━━━━━━━━━━━━ 2s 772us/step

# %%
#save prediction to embdf
embdf['score_nn'] = pred

# %%
#view embdf
embdf.head()
# Out:
#             relationships                                          embedding  \
# 0     ['low pregnancies']  [0.3559499979019165, 0.017154032364487648, -0....
# 1  ['normal pregnancies']  [0.21517100930213928, 0.09962455183267593, 0.1...
# 2    ['high pregnancies']  [0.1451621651649475, 0.012034144252538681, -0....
# 3         ['low glucose']  [0.07380708307027817, 0.07721707224845886, 0.0...
# 4      ['normal glucose']  [0.4024839997291565, -0.0163387693464756, -0.0...
#
#    score_rf  score_xgb  score_svm  score_nb  score_nn
# 0         0          0          0         0  0.170097
# 1         0          0          0         0  0.298908
# 2         0          0          0         0  0.517344
# 3         0          0          0         0  0.121242
# 4         0          0          0         0  0.048572

# %%
#create binary column for nn
embdf['score_nn_binary'] = embdf['score_nn'].apply(lambda x: 1 if x>=.5 else 0)

# %%
#save embdf
embdf.to_csv("data/predictedscores.csv")
